# %% [markdown]
# # NER - Named Entity Recognition

# %% [markdown]
# A program that finds the names of places, people and organizations in a text.

# %% [markdown]
# NLP - Translate
#
# Lang Detect
#
# POS - Part of Speech
#
# Sentiment analysis
#
# Text Classification
#
# Text Generation - LSTM Long Short Time Memory
#
# Text Summarization
#
# NER - Named Entity Recognition
#
# Topic Modelling

# %%
#!pip install -U spacy

# %%
#!spacy download en_core_web_sm

# %%
import spacy
from spacy import displacy
NER = spacy.load('en_core_web_sm')

# %%
text="""Zafer Acar loves NLP and artificial intelligence. Python is a great programming language.
The Turkish Space Agency is the national space agency of Turkey, headquartered in Ankara.
It operates under the Department of Space which is directly overseen
by the President of Turkey and administor of TUA is Serdar Hüseyin Yildirm."""

# %%
text1 = NER(text)

# %%
for word in text1.ents:
    print(word.text, word.label_)
# Out:
# Zafer Acar PERSON
# NLP ORG
# The Turkish Space Agency ORG
# Turkey GPE
# Ankara GPE
# the Department of Space ORG
# Turkey GPE
# TUA ORG
# Serdar Hüseyin Yildirm PERSON

# %%
spacy.explain("ORG")
# Out:
# 'Companies, agencies, institutions, etc.'

# %%
spacy.explain("GPE")
# Out:
# 'Countries, cities, states'

# %%
spacy.explain("PERSON")
# Out:
# 'People, including fictional'

# %%
displacy.render(text1)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e0296f38442642f1b81b394528d80a9d-0" class="displacy" width="9500" height="574.5" direction="ltr" style="max-width: none; height: 574.5px; color: #000000; background: #ffffff; font-family: Arial; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="50">Zafer</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
#     <tspan class="displacy-word" fill="currentColor" x="225">Acar</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="225">PROPN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="484.5">
# ...

# %%
displacy.render(text1, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Zafer Acar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  loves
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     NLP
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and artificial intelligence. Python is a great programming language.<br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     The Turkish Space Agency
# ...
